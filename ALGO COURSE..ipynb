# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL",start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2009-12-31    7.611786    7.619643    7.520000    7.526071    6.405577
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.505280
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.516525
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.412874
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.401018
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  130.205780
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.862671
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  133.066986
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.932388
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.916153
#
#                Volume
# Date
# 2009-12-31  352410800
# 2010-01-04  493729600
# 2010-01-05  601904800
# ...

# %%
ticker = ["SPY","AAPL","KO"]

# %%
Stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
Stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2009-12-31    6.405577  19.068235   86.979065    7.526071  28.500000
# 2010-01-04    6.505279  19.081614   88.454193    7.643214  28.520000
# 2010-01-05    6.516528  18.850794   88.688370    7.656429  28.174999
# 2010-01-06    6.412873  18.844099   88.750809    7.534643  28.165001
# 2010-01-07    6.401018  18.797264   89.125435    7.520714  28.094999
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.205765  50.318050  358.332642  131.970001  53.439999
# 2020-12-28  134.862671  50.995991  361.411041  136.690002  54.160000
# 2020-12-29  133.067017  50.967747  360.721527  134.869995  54.130001
# 2020-12-30  131.932388  51.259636  361.236237  133.720001  54.439999
# 2020-12-31  130.916138  51.636269  363.071564  132.690002  54.840000
#
# ...

# %%
Stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2770 entries, 2009-12-31 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2770 non-null   float64
#  1   (Adj Close, KO)    2770 non-null   float64
#  2   (Adj Close, SPY)   2770 non-null   float64
#  3   (Close, AAPL)      2770 non-null   float64
#  4   (Close, KO)        2770 non-null   float64
#  5   (Close, SPY)       2770 non-null   float64
#  6   (High, AAPL)       2770 non-null   float64
#  7   (High, KO)         2770 non-null   float64
#  8   (High, SPY)        2770 non-null   float64
#  9   (Low, AAPL)        2770 non-null   float64
#  10  (Low, KO)          2770 non-null   float64
#  11  (Low, SPY)         2770 non-null   float64
#  12  (Open, AAPL)       2770 non-null   float64
#  13  (Open, KO)         2770 non-null   float64
#  14  (Open, SPY)        2770 non-null   float64
# ...

# %%
Stocks.to_csv("StocksYT")

# %%
Stocks = pd.read_csv("StocksYT")

# %%
Stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1        Adj Close.2  \
# 0            NaN                AAPL                  KO                SPY
# 1           Date                 NaN                 NaN                NaN
# 2     2009-12-31   6.405576705932617  19.068235397338867  86.97906494140625
# 3     2010-01-04   6.505278587341309  19.081613540649414  88.45419311523438
# 4     2010-01-05   6.516528129577637  18.850793838500977  88.68836975097656
# ...          ...                 ...                 ...                ...
# 2767  2020-12-24   130.2057647705078  50.318050384521484  358.3326416015625
# 2768  2020-12-28   134.8626708984375   50.99599075317383  361.4110412597656
# 2769  2020-12-29   133.0670166015625   50.96774673461914  360.7215270996094
# 2770  2020-12-30  131.93238830566406   51.25963592529297  361.2362365722656
# 2771  2020-12-31   130.9161376953125  51.636268615722656  363.0715637207031
#
# ...

# %%
Stocks = pd.read_csv("StocksYT", header=[0,1])

# %%
Stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2009-12-31    6.405577  19.068235   86.979065    7.526071
# 2            2010-01-04    6.505279  19.081614   88.454193    7.643214
# 3            2010-01-05    6.516528  18.850794   88.688370    7.656429
# 4            2010-01-06    6.412873  18.844099   88.750809    7.534643
# ...                 ...         ...        ...         ...         ...
# 2766         2020-12-24  130.205765  50.318050  358.332642  131.970001
# 2767         2020-12-28  134.862671  50.995991  361.411041  136.690002
# 2768         2020-12-29  133.067017  50.967747  360.721527  134.869995
# 2769         2020-12-30  131.932388  51.259636  361.236237  133.720001
# 2770         2020-12-31  130.916138  51.636269  363.071564  132.690002
#
# ...

# %%
Stocks = pd.read_csv("StocksYT", header=[0,1],index_col=[0])
Stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2009-12-31    6.405577  19.068235   86.979065    7.526071  28.500000
# 2010-01-04    6.505279  19.081614   88.454193    7.643214  28.520000
# 2010-01-05    6.516528  18.850794   88.688370    7.656429  28.174999
# 2010-01-06    6.412873  18.844099   88.750809    7.534643  28.165001
# 2010-01-07    6.401018  18.797264   89.125435    7.520714  28.094999
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.205765  50.318050  358.332642  131.970001  53.439999
# 2020-12-28  134.862671  50.995991  361.411041  136.690002  54.160000
# 2020-12-29  133.067017  50.967747  360.721527  134.869995  54.130001
# 2020-12-30  131.932388  51.259636  361.236237  133.720001  54.439999
# 2020-12-31  130.916138  51.636269  363.071564  132.690002  54.840000
#
# ...

# %%
Stocks = pd.read_csv("StocksYT", header=[0,1],index_col=[0],parse_dates=[0])
Stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2009-12-31    6.405577  19.068235   86.979065    7.526071  28.500000
# 2010-01-04    6.505279  19.081614   88.454193    7.643214  28.520000
# 2010-01-05    6.516528  18.850794   88.688370    7.656429  28.174999
# 2010-01-06    6.412873  18.844099   88.750809    7.534643  28.165001
# 2010-01-07    6.401018  18.797264   89.125435    7.520714  28.094999
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.205765  50.318050  358.332642  131.970001  53.439999
# 2020-12-28  134.862671  50.995991  361.411041  136.690002  54.160000
# 2020-12-29  133.067017  50.967747  360.721527  134.869995  54.130001
# 2020-12-30  131.932388  51.259636  361.236237  133.720001  54.439999
# 2020-12-31  130.916138  51.636269  363.071564  132.690002  54.840000
#
# ...

# %%
Stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
#convert the multiindex into a tuple
Stocks.columns=Stocks.columns.to_flat_index()

# %%
Stocks.columns
#its now a single index from a multiindex
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
Stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2009-12-31           6.405577        19.068235         86.979065
# 2010-01-04           6.505279        19.081614         88.454193
# 2010-01-05           6.516528        18.850794         88.688370
# 2010-01-06           6.412873        18.844099         88.750809
# 2010-01-07           6.401018        18.797264         89.125435
# ...                       ...              ...               ...
# 2020-12-24         130.205765        50.318050        358.332642
# 2020-12-28         134.862671        50.995991        361.411041
# 2020-12-29         133.067017        50.967747        360.721527
# 2020-12-30         131.932388        51.259636        361.236237
# 2020-12-31         130.916138        51.636269        363.071564
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2009-12-31       7.526071    28.500000    111.440002      7.619643
# ...

# %%
Stocks.columns=pd.MultiIndex.from_tuples(Stocks.columns)
Stocks
#this converts the dataset back to a multiindex formart
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2009-12-31    6.405577  19.068235   86.979065    7.526071  28.500000
# 2010-01-04    6.505279  19.081614   88.454193    7.643214  28.520000
# 2010-01-05    6.516528  18.850794   88.688370    7.656429  28.174999
# 2010-01-06    6.412873  18.844099   88.750809    7.534643  28.165001
# 2010-01-07    6.401018  18.797264   89.125435    7.520714  28.094999
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.205765  50.318050  358.332642  131.970001  53.439999
# 2020-12-28  134.862671  50.995991  361.411041  136.690002  54.160000
# 2020-12-29  133.067017  50.967747  360.721527  134.869995  54.130001
# 2020-12-30  131.932388  51.259636  361.236237  133.720001  54.439999
# 2020-12-31  130.916138  51.636269  363.071564  132.690002  54.840000
#
# ...

# %%
Stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2770.000000  2770.000000  2770.000000  2770.000000  2770.000000
# mean     31.681471    33.219810   184.783997    33.768060    41.315493
# std      24.714849     8.444675    70.774616    24.573372     6.811654
# min       5.837761    16.890404    80.476776     6.858929    25.014999
# 25%      15.254120    27.438028   116.583988    17.471964    37.645000
# 50%      24.642287    32.764568   178.629333    26.985000    41.759998
# 75%      41.097494    38.813550   245.579182    42.996250    45.549999
# max     134.862671    54.743851   363.071564   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2770.000000  2770.000000  2770.000000  2770.000000  2770.000000
# ...

# %%
close=Stocks.loc[:,"Close"].copy()
#we'll store tha data in "close"

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2009-12-31    7.526071  28.500000  111.440002
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2770 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
#we need the matplotlib for plotting graphs

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()
#legend function makes the graph neat.
#we are plotting the close stock prices.

# %%
#Normalisation
#purpose of this is to have one single data point where they all start.
close.iloc[0,0]
#with this i get the first value on the first row and first cloumn
# Out:
# 7.526071071624756

# %%
close.AAPL
# Out:
# Date
# 2009-12-31      7.526071
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2770, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
#we have just normalised this data using the div function
# Out:
# Date
# 2009-12-31     1.000000
# 2010-01-04     1.015565
# 2010-01-05     1.017321
# 2010-01-06     1.001139
# 2010-01-07     0.999288
#                 ...
# 2020-12-24    17.535046
# 2020-12-28    18.162199
# 2020-12-29    17.920372
# 2020-12-30    17.767571
# 2020-12-31    17.630713
# Name: AAPL, Length: 2770, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
#we could use the mul function which is used for multiplication, in this case by 100. this is  also a way of normalising, and in this case in terms of hundreds.
# Out:
# Date
# 2009-12-31     100.000000
# 2010-01-04     101.556498
# 2010-01-05     101.732082
# 2010-01-06     100.113899
# 2010-01-07      99.928817
#                  ...
# 2020-12-24    1753.504584
# 2020-12-28    1816.219926
# 2020-12-29    1792.037224
# 2020-12-30    1776.757088
# 2020-12-31    1763.071345
# Name: AAPL, Length: 2770, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
#with  this line of code i get all the close stock price normalised to 100.
#its the one time code to normalise data.
#we use the close.div(instead of close.AAPL) so that we have all the three stock prices normalised as shown below.
# Out:
#                    AAPL          KO         SPY
# Date
# 2009-12-31   100.000000  100.000000  100.000000
# 2010-01-04   101.556498  100.070177  101.695979
# 2010-01-05   101.732082   98.859646  101.965178
# 2010-01-06   100.113899   98.824565  102.036968
# 2010-01-07    99.928817   98.578945  102.467696
# ...                 ...         ...         ...
# 2020-12-24  1753.504584  187.508767  331.119878
# 2020-12-28  1816.219926  190.035087  333.964470
# 2020-12-29  1792.037224  189.929828  333.327336
# 2020-12-30  1776.757088  191.017539  333.802927
# 2020-12-31  1763.071345  192.421053  335.498920
#
# [2770 rows x 3 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)
#we store the data in a normclose so that we can plot it.

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()
#we add the normclose so that we plot the graph that's been normalised

# %%
aapl=close.AAPL.copy().to_frame()
#This line of code will be used to copy the close prices of apple to appl and also cnovert the data to a dataframe thru the "to_frame" function.

# %%
aapl
# Out:
#                   AAPL
# Date
# 2009-12-31    7.526071
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2770 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2009-12-31         NaN
# 2010-01-04    7.526071
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2770 rows x 1 columns]

# %%
aapl["lag1"]=aapl.shift(periods=1)
#we need to create a new column for the lags and leave the original coulmn.
#here we just created a new column which will now contain the lagged values of aapl.

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2009-12-31    7.526071         NaN
# 2010-01-04    7.643214    7.526071
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2770 rows x 2 columns]

# %%
aapl["Diff"]=aapl.AAPL.sub(aapl.lag1)
#from here we'll get subtracted data i.e lag minus the actual price the previous day.
#we've also stored the difference in a column called "Diff".

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2009-12-31    7.526071         NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2770 rows x 3 columns]

# %%
aapl["%change"]=aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
#here we have looked for the percentage change by dividing the prices to their lags
#we also stored the percentage change data.

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %change
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2770 rows x 4 columns]

# %%
aapl["Diff2"]=aapl.AAPL.diff(periods=1)
#This is another way of calulating the percentage change in prices. 
#its a one time code an can skip all other lines of code.

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %change     Diff2
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498  0.117143
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999
#
# [2770 rows x 5 columns]

# %%
aapl["% change 2"]=aapl.AAPL.pct_change(periods=1).mul(100)
#another way of calculating the percentage returns.

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %change     Diff2  % change 2
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN       NaN         NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498  0.117143    1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999   -0.770265
#
# [2770 rows x 6 columns]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %change     Diff2  % change 2
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN       NaN         NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498  0.117143    1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999   -0.770265
#
# [2770 rows x 6 columns]

# %%
del aapl["Diff2"]
#deleting columns for diff2, lag1 and %change

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %change  % change 2
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN         NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498    1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.172893    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871   -0.184871
# ...                ...         ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265   -0.770265
#
# [2770 rows x 5 columns]

# %%
del aapl["lag1"]

# %%
aapl
# Out:
#                   AAPL      Diff   %change  % change 2
# Date
# 2009-12-31    7.526071       NaN       NaN         NaN
# 2010-01-04    7.643214  0.117143  1.556498    1.556498
# 2010-01-05    7.656429  0.013215  0.172893    0.172893
# 2010-01-06    7.534643 -0.121786 -1.590632   -1.590632
# 2010-01-07    7.520714 -0.013929 -0.184871   -0.184871
# ...                ...       ...       ...         ...
# 2020-12-24  131.970001  1.009995  0.771224    0.771224
# 2020-12-28  136.690002  4.720001  3.576571    3.576571
# 2020-12-29  134.869995 -1.820007 -1.331485   -1.331485
# 2020-12-30  133.720001 -1.149994 -0.852668   -0.852668
# 2020-12-31  132.690002 -1.029999 -0.770265   -0.770265
#
# [2770 rows x 4 columns]

# %%
aapl
# Out:
#                   AAPL      Diff   %change  % change 2
# Date
# 2009-12-31    7.526071       NaN       NaN         NaN
# 2010-01-04    7.643214  0.117143  1.556498    1.556498
# 2010-01-05    7.656429  0.013215  0.172893    0.172893
# 2010-01-06    7.534643 -0.121786 -1.590632   -1.590632
# 2010-01-07    7.520714 -0.013929 -0.184871   -0.184871
# ...                ...       ...       ...         ...
# 2020-12-24  131.970001  1.009995  0.771224    0.771224
# 2020-12-28  136.690002  4.720001  3.576571    3.576571
# 2020-12-29  134.869995 -1.820007 -1.331485   -1.331485
# 2020-12-30  133.720001 -1.149994 -0.852668   -0.852668
# 2020-12-31  132.690002 -1.029999 -0.770265   -0.770265
#
# [2770 rows x 4 columns]

# %%
aapl.rename(columns = {'% change 2':'change'},inplace = True)
#This is code if you want to change the coulumn name of a data set

# %%
aapl
#now we have the column name changed.
# Out:
#                   AAPL      Diff   %change    change
# Date
# 2009-12-31    7.526071       NaN       NaN       NaN
# 2010-01-04    7.643214  0.117143  1.556498  1.556498
# 2010-01-05    7.656429  0.013215  0.172893  0.172893
# 2010-01-06    7.534643 -0.121786 -1.590632 -1.590632
# 2010-01-07    7.520714 -0.013929 -0.184871 -0.184871
# ...                ...       ...       ...       ...
# 2020-12-24  131.970001  1.009995  0.771224  0.771224
# 2020-12-28  136.690002  4.720001  3.576571  3.576571
# 2020-12-29  134.869995 -1.820007 -1.331485 -1.331485
# 2020-12-30  133.720001 -1.149994 -0.852668 -0.852668
# 2020-12-31  132.690002 -1.029999 -0.770265 -0.770265
#
# [2770 rows x 4 columns]

# %%
aapl.AAPL.resample("M").last()
#This line of code helps in converting the data from daily data to monthly data using the "resample" function.
#The ".last "function will now show the last day of the month.
# Out:
# Date
# 2009-12-31      7.526071
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 133, dtype: float64

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
#lets assume you want to do the last bussines day of the month
#Then last part of the code will now show the percentage change per month.
#end of jan the returns were -8% end of february returns were 6% e.t.c
# Out:
# Date
# 2009-12-31          NaN
# 2010-01-29    -8.859672
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 133, dtype: float64

# %%
ret = aapl.pct_change().dropna()
#here we've created a new variable called ret which are the daily returns.
#the "dropna" function is to remove the NaN row in the dataset to make it more cleaner.
#this ret variable now has the percentage change of AAPL stock

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2768 entries, 2010-01-05 to 2020-12-31
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   AAPL     2768 non-null   float64
#  1   Diff     2768 non-null   float64
#  2   %change  2768 non-null   float64
#  3   change   2768 non-null   float64
# dtypes: float64(4)
# memory usage: 108.1 KB

# %%
ret.plot(kind="hist",bins=(100),figsize(15,8))
plt.show()
# Out:
#   Input In [57]
#     ret.plot(kind="hist",bins=(100),figsize(15,8))
#                                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
daily_mean_return=ret.mean()
daily_mean_return
# Out:
# AAPL       0.001191
# Diff            NaN
# %change         NaN
# change          NaN
# dtype: float64

# %%
daily_var=ret.var()
daily_var
# Out:
# AAPL       0.000318
# Diff            NaN
# %change         NaN
# change          NaN
# dtype: float64

# %%
std_daily=np.sqrt(daily_var)
#we used the numpy library to do the calclations for sqrt.

# %%
std_daily
# Out:
# AAPL       0.017843
# Diff            NaN
# %change         NaN
# change          NaN
# dtype: float64

# %%
ret.std()
#this is another method of calculating std
# Out:
# AAPL       0.017843
# Diff            NaN
# %change         NaN
# change          NaN
# dtype: float64

# %%
annual_mean_return=daily_mean_return*252
annual_mean_return
#daily returns mltiply by 252 trading days in a year.
# Out:
# AAPL       0.300134
# Diff            NaN
# %change         NaN
# change          NaN
# dtype: float64

# %%
annual_var=daily_var*252
annual_var
# Out:
# AAPL       0.080226
# Diff            NaN
# %change         NaN
# change          NaN
# dtype: float64

# %%
annual_std=np.sqrt(annual_var)

# %%
annual_std
# Out:
# AAPL       0.283242
# Diff            NaN
# %change         NaN
# change          NaN
# dtype: float64

# %%
ticker= ["AAPL","KO","IBM","DIS","MSFT"]

# %%
Stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
close=Stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
#i want to get the percentage change in returns for all the companies.
# Out:
#                 AAPL       DIS       IBM        KO      MSFT
# Date
# 2010-01-04  0.015565 -0.005581  0.011841  0.000702  0.015420
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897

# %%
ret.describe().T
#The .T is used for transposing the dataset.
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2769.0  0.001196  0.017841 -0.128647 -0.007121  0.000905  0.010384
# DIS   2769.0  0.000747  0.015715 -0.129846 -0.006209  0.000610  0.007898
# IBM   2769.0  0.000086  0.014132 -0.128507 -0.006321  0.000289  0.006759
# KO    2769.0  0.000298  0.011086 -0.096725 -0.004696  0.000440  0.005705
# MSFT  2769.0  0.000846  0.016012 -0.147390 -0.006936  0.000655  0.008638
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
#we only want to get the mean and std of all the companies we sue the .loc code for that.
# Out:
#           mean       std
# AAPL  0.001196  0.017841
# DIS   0.000747  0.015715
# IBM   0.000086  0.014132
# KO    0.000298  0.011086
# MSFT  0.000846  0.016012

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["mean"]*np.sqrt(252)
summary
#we now use this lines of code to get the annnalised mean and std for all the companies
#"the brackets used in this case are used ot show whatever exsits"
# Out:
#           mean       std
# AAPL  0.301443  4.785253
# DIS   0.188119  2.986304
# IBM   0.021718  0.344768
# KO    0.075128  1.192619
# MSFT  0.213242  3.385105

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annualrisk(std)",fontsize=15)
plt.ylabel("Annualrisk return",fontsize=15)
plt.title("Risk/Return",fontsize=20)
#this is a scatter plot for the mean and st.deviation.
#we are going to create a for-loop that is going to name each scatter point in the graph.
#this is a scatter plot for the mean and st.deviation.
#the .annoatate function is used to plot values with their labels next to them.
#the .xlabel functionis used to label the x-axis.
#the .ylabel functionis used to label the y-axis
#the .title functionis used to give the graph a title.
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %%
#what does a for-loop do?
fruits=["apple","pineapple","orange"]
for i in fruits:
    print(i)
fruits[1]
#it goes picking the object specified in the array.
# Out:
# apple
# pineapple
# orange
# 'pineapple'

# %% [markdown]
# ## CORRELATION AND COVARIANCE.

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT
# Date
# 2010-01-04  0.015565 -0.005581  0.011841  0.000702  0.015420
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897
# ...              ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338
#
# [2769 rows x 5 columns]

# %%
ret.cov()
#the .cov is used for finding the covariance of the matrix.
# Out:
#           AAPL       DIS       IBM        KO      MSFT
# AAPL  0.000318  0.000114  0.000110  0.000067  0.000158
# DIS   0.000114  0.000247  0.000111  0.000085  0.000121
# IBM   0.000110  0.000111  0.000200  0.000079  0.000121
# KO    0.000067  0.000085  0.000079  0.000123  0.000076
# MSFT  0.000158  0.000121  0.000121  0.000076  0.000256

# %%
ret.corr()
#this is the code for correlation.
# Out:
#           AAPL       DIS       IBM        KO      MSFT
# AAPL  1.000000  0.408336  0.436236  0.339184  0.554168
# DIS   0.408336  1.000000  0.497577  0.486494  0.480239
# IBM   0.436236  0.497577  1.000000  0.502384  0.533257
# KO    0.339184  0.486494  0.502384  1.000000  0.429696
# MSFT  0.554168  0.480239  0.533257  0.429696  1.000000

# %%
import seaborn as sns
#we are gonna use this library to draw a heatmap. it will be used to show the cov and corr.

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()
#this is the code that was used to show the heatmap for the correlation of the returns.
#SPY has a higher correlation to all the stocks since ot contains some of the tickers in its basket.

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])
#I created a random data frame df using the pandas DataFrame function.
#the index, data and columns are to create the info inside the dataframe.

# %% [markdown]
# ## Simple returns and Log returns.

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
#the avg return
#mean returns are very misleading
# Out:
# Price    0.2
# dtype: float64

# %%
logreturns = np.log(df/df.shift(1)).dropna()
logreturns
#we use the log function from the numpy library to get the log returns.
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
#Arithmetically
#we clearly get the price as at 2018 to be 95
# Out:
# Price    95.0
# dtype: float64

# %% [markdown]
# ## Calculating a simple moving average

# %%
SPY = yf.download("SPY")
# we've downlaoded data from 1900 to now on the SPY.
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()
spy
#here we have the close price of SPY in a dataframe, using the .to frame function
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-02-08  410.649994
# 2023-02-09  407.089996
# 2023-02-10  408.040009
# 2023-02-13  412.829987
# 2023-02-14  412.640015
#
# [7566 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()
#here we just created a graph of the close of the SPY.
#We use the plt.legend to show,on the upper left, which line is being drawn.

# %%
spy_roll = spy.rolling(window=10)
#we have used the rolling function to calculate the MA

# %%
spy_roll = spy_roll.mean()
#We have now taken the mean of the rolled values.

# %%
spy_roll
#the first few values are missing since we are calculating MA(10)
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-02-08  409.309998
# 2023-02-09  409.543997
# 2023-02-10  409.779999
# 2023-02-13  411.003998
# 2023-02-14  411.619998
#
# [7566 rows x 1 columns]

# %%
spy_roll.head(15)
#use the .head function for the number of days that you want to start calculating the MA.
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()
#to get the median valueas well.
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-02-08  410.239990
# 2023-02-09  410.239990
# 2023-02-10  410.239990
# 2023-02-13  410.724991
# 2023-02-14  411.574997
#
# [7566 rows x 1 columns]

# %%
spy.rolling(window=10).max()
#get the maximum value for the last ten days
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-02-08  416.779999
# 2023-02-09  416.779999
# 2023-02-10  416.779999
# 2023-02-13  416.779999
# 2023-02-14  416.779999
#
# [7566 rows x 1 columns]

# %%
spy.rolling(window=10,min_periods=5).max().head(15)
#we set a minimum period of 5, basically that is where the calculations are going to begin at the 5th value.
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()
#we introduced a new column SMA50. This is how we calculate the 50MA

# %%
spy
# Out:
#                  Close       SMA50
# Date
# 1993-01-29   43.937500         NaN
# 1993-02-01   44.250000         NaN
# 1993-02-02   44.343750         NaN
# 1993-02-03   44.812500         NaN
# 1993-02-04   45.000000         NaN
# ...                ...         ...
# 2023-02-08  410.649994  395.325999
# 2023-02-09  407.089996  395.549599
# 2023-02-10  408.040009  395.805799
# 2023-02-13  412.829987  395.908799
# 2023-02-14  412.640015  396.013999
#
# [7566 rows x 2 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()
#we have plotted the graph of both the SMA50 and closing prices.

# %%
spy["SMA200"]=spy.Close.rolling(window=200,min_periods=200).mean()
spy
# Out:
#                  Close       SMA50     SMA200
# Date
# 1993-01-29   43.937500         NaN        NaN
# 1993-02-01   44.250000         NaN        NaN
# 1993-02-02   44.343750         NaN        NaN
# 1993-02-03   44.812500         NaN        NaN
# 1993-02-04   45.000000         NaN        NaN
# ...                ...         ...        ...
# 2023-02-08  410.649994  395.325999  393.72110
# 2023-02-09  407.089996  395.549599  393.61400
# 2023-02-10  408.040009  395.805799  393.57370
# 2023-02-13  412.829987  395.908799  393.55150
# 2023-02-14  412.640015  396.013999  393.47565
#
# [7566 rows x 3 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %% [markdown]
# ## NOW WE PLOT FOR THE EMA, exponentially moving average.

# %%
spy["EMA100"]=spy.Close.ewm(span=50,min_periods=50).mean()
spy
# Out:
#                  Close       SMA50     SMA200      EMA100
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN
# 1993-02-01   44.250000         NaN        NaN         NaN
# 1993-02-02   44.343750         NaN        NaN         NaN
# 1993-02-03   44.812500         NaN        NaN         NaN
# 1993-02-04   45.000000         NaN        NaN         NaN
# ...                ...         ...        ...         ...
# 2023-02-08  410.649994  395.325999  393.72110  396.926173
# 2023-02-09  407.089996  395.549599  393.61400  397.324754
# 2023-02-10  408.040009  395.805799  393.57370  397.744960
# 2023-02-13  412.829987  395.908799  393.55150  398.336530
# 2023-02-14  412.640015  396.013999  393.47565  398.897451
#
# [7566 rows x 4 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
spy["Day"]=spy.index.day_name()
spy
#this line of code helps in determining the specific days of the week.
# Out:
#                  Close       SMA50     SMA200      EMA100        Day
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN     Friday
# 1993-02-01   44.250000         NaN        NaN         NaN     Monday
# 1993-02-02   44.343750         NaN        NaN         NaN    Tuesday
# 1993-02-03   44.812500         NaN        NaN         NaN  Wednesday
# 1993-02-04   45.000000         NaN        NaN         NaN   Thursday
# ...                ...         ...        ...         ...        ...
# 2023-02-08  410.649994  395.325999  393.72110  396.926173  Wednesday
# 2023-02-09  407.089996  395.549599  393.61400  397.324754   Thursday
# 2023-02-10  408.040009  395.805799  393.57370  397.744960     Friday
# 2023-02-13  412.829987  395.908799  393.55150  398.336530     Monday
# 2023-02-14  412.640015  396.013999  393.47565  398.897451    Tuesday
#
# [7566 rows x 5 columns]

# %%
spy["Quarter"]=spy.index.quarter
#will show the various qaurters in the years.

# %%
spy
# Out:
#                  Close       SMA50     SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN        NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN        NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN        NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN        NaN         NaN   Thursday        1
# ...                ...         ...        ...         ...        ...      ...
# 2023-02-08  410.649994  395.325999  393.72110  396.926173  Wednesday        1
# 2023-02-09  407.089996  395.549599  393.61400  397.324754   Thursday        1
# 2023-02-10  408.040009  395.805799  393.57370  397.744960     Friday        1
# 2023-02-13  412.829987  395.908799  393.55150  398.336530     Monday        1
# 2023-02-14  412.640015  396.013999  393.47565  398.897451    Tuesday        1
#
# [7566 rows x 6 columns]

# %%
SPY=yf.download("SPY")
#WE DOWNLOADED THE DATA AGAIN SO THAT WE HAVE THE ORIGINAL PRICE DATA.
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-02-08  410.649994
# 2023-02-09  407.089996
# 2023-02-10  408.040009
# 2023-02-13  412.829987
# 2023-02-14  412.640015
#
# [7566 rows x 1 columns]

# %%
all_days=pd.date_range(start="2010-12-31",end="2020-01-01",freq="D")
all_days
#we want to get all the days that are present in the data frame. some days maybe missing, weekends, holidays.
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
spy=spy.reindex(all_days)
spy
#As you can see we after using the reindex function we now have NaN days, showing holidays and weekends
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method="ffill")
#its used to fill the NaN gaps in the data frame by moving the previous prices into the gaps.
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  322.859985
# 2019-12-29  322.859985
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01  321.859985
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method="bfill")
#fills using the future prices
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  127.050003
# 2011-01-02  127.050003
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  321.079987
# 2019-12-29  321.079987
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
SPY = yf.download("SPY",interval="1wk")
SPY
#CODE FOR WEEKLY DATA.
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   25.218220
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.810122
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.594887
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   25.002991
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.487272
# ...                ...         ...         ...         ...         ...
# 2023-01-23  396.720001  408.160004  393.559998  405.679993  405.679993
# 2023-01-30  402.799988  418.309998  400.279999  412.350006  412.350006
# 2023-02-06  409.790009  416.489990  405.010010  408.040009  408.040009
# 2023-02-13  408.720001  415.049988  408.239990  412.640015  412.640015
# 2023-02-14  411.239990  415.049988  408.519989  412.640015  412.640015
#
#                  Volume
# Date
# ...

# %% [markdown]
# ## CUMMULATIVE RETURNS AND DRAWDOWNS etc..

# %%
Micro=yf.download("MSFT")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Micro
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060809
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062980
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064067
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062437
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061351
# ...                ...         ...         ...         ...         ...
# 2023-02-08  273.200012  276.760010  266.209991  266.730011  266.730011
# 2023-02-09  273.799988  273.980011  262.799988  263.619995  263.619995
# 2023-02-10  261.529999  264.089996  260.660004  263.100006  263.100006
# 2023-02-13  267.640015  274.600006  267.149994  271.320007  271.320007
# 2023-02-14  272.670013  274.970001  269.279999  272.170013  272.170013
#
#                 Volume
# Date
# 1986-03-13  1031788800
# 1986-03-14   308160000
# 1986-03-17   133171200
# ...

# %%
micro=Micro.Close.to_frame()
micro
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-02-08  266.730011
# 2023-02-09  263.619995
# 2023-02-10  263.100006
# 2023-02-13  271.320007
# 2023-02-14  272.170013
#
# [9307 rows x 1 columns]

# %%
micro["d_returns"]=np.log(micro.div(micro.shift(1)))

# %%
micro
# Out:
#                  Close  d_returns
# Date
# 1986-03-13    0.097222        NaN
# 1986-03-14    0.100694   0.035089
# 1986-03-17    0.102431   0.017103
# 1986-03-18    0.099826  -0.025761
# 1986-03-19    0.098090  -0.017543
# ...                ...        ...
# 2023-02-08  266.730011  -0.003107
# 2023-02-09  263.619995  -0.011728
# 2023-02-10  263.100006  -0.001974
# 2023-02-13  271.320007   0.030765
# 2023-02-14  272.170013   0.003128
#
# [9307 rows x 2 columns]

# %%
micro.dropna(inplace=True)

# %%
micro
# Out:
#                  Close  d_returns
# Date
# 1986-03-14    0.100694   0.035089
# 1986-03-17    0.102431   0.017103
# 1986-03-18    0.099826  -0.025761
# 1986-03-19    0.098090  -0.017543
# 1986-03-20    0.095486  -0.026906
# ...                ...        ...
# 2023-02-08  266.730011  -0.003107
# 2023-02-09  263.619995  -0.011728
# 2023-02-10  263.100006  -0.001974
# 2023-02-13  271.320007   0.030765
# 2023-02-14  272.170013   0.003128
#
# [9306 rows x 2 columns]

# %%
micro.d_returns.sum()
#this line of code is ude to calculate BUY and HOLD returns, basically it sums the returns. which is 7.90
# Out:
# 7.937185172370414

# %%
#What if we invested $1 in microsoft in 14th march 1986, what wouldit be worth now.
#we are using the numpy and pandas library for this, and also exponential
#$1 dollar invested would be $2720.166 today.
np.exp(micro.d_returns.sum())
# Out:
# 2799.469383663732

# %%
micro["cummreturns"]=micro.d_returns.cumsum().apply(np.exp)
micro
#this line of code will be used to to calculate the cumulative returns from 1986 to 2022...at the end we shoud get $2720
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1986-03-14    0.100694   0.035089     1.035712
# 1986-03-17    0.102431   0.017103     1.053578
# 1986-03-18    0.099826  -0.025761     1.026784
# 1986-03-19    0.098090  -0.017543     1.008928
# 1986-03-20    0.095486  -0.026906     0.982144
# ...                ...        ...          ...
# 2023-02-08  266.730011  -0.003107  2743.514945
# 2023-02-09  263.619995  -0.011728  2711.526137
# 2023-02-10  263.100006  -0.001974  2706.177667
# 2023-02-13  271.320007   0.030765  2790.726444
# 2023-02-14  272.170013   0.003128  2799.469384
#
# [9306 rows x 3 columns]

# %%
micro.cummreturns.plot(figsize=(12,8),fontsize=12,title="Microsoft Buy and Hold")
#this will plot a graph of the cummlative returns.
# Out:
# <AxesSubplot:title={'center':'Microsoft Buy and Hold'}, xlabel='Date'>

# %%
micro.d_returns.mean()*252
#annual mean returns
# Out:
# 0.21493344760770913

# %%
micro.d_returns.std()*np.sqrt(252)
#the annual standard deviation
# Out:
# 0.3401439500071477

# %% [markdown]
# ## Calculations of drawdowns

# %%
micro["cummax"]=micro.cummreturns.cummax()
micro
#we will need to calculate the cummulative maximum inorder to calc the drawdowns.
#so we have created a cummulative maximum cloumn.
# Out:
#                  Close  d_returns  cummreturns       cummax
# Date
# 1986-03-14    0.100694   0.035089     1.035712     1.035712
# 1986-03-17    0.102431   0.017103     1.053578     1.053578
# 1986-03-18    0.099826  -0.025761     1.026784     1.053578
# 1986-03-19    0.098090  -0.017543     1.008928     1.053578
# 1986-03-20    0.095486  -0.026906     0.982144     1.053578
# ...                ...        ...          ...          ...
# 2023-02-08  266.730011  -0.003107  2743.514945  3529.139331
# 2023-02-09  263.619995  -0.011728  2711.526137  3529.139331
# 2023-02-10  263.100006  -0.001974  2706.177667  3529.139331
# 2023-02-13  271.320007   0.030765  2790.726444  3529.139331
# 2023-02-14  272.170013   0.003128  2799.469384  3529.139331
#
# [9306 rows x 4 columns]

# %%
micro[["cummreturns","cummax"]].plot(figsize=(12,8),fontsize=12,title="Microsoft Buy and Hold and Cummulative maximum")
plt.show()
#we have created a graph that shows the high of each of the new high that has been created
#useful if trying to come up with a 52-week high or breakout strategy

# %%
#to calculate the drawdowns.
micro["drawdowns"]=micro["cummax"]-micro["cummreturns"]
micro
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdowns
# Date
# 1986-03-14    0.100694   0.035089     1.035712     1.035712    0.000000
# 1986-03-17    0.102431   0.017103     1.053578     1.053578    0.000000
# 1986-03-18    0.099826  -0.025761     1.026784     1.053578    0.026794
# 1986-03-19    0.098090  -0.017543     1.008928     1.053578    0.044650
# 1986-03-20    0.095486  -0.026906     0.982144     1.053578    0.071434
# ...                ...        ...          ...          ...         ...
# 2023-02-08  266.730011  -0.003107  2743.514945  3529.139331  785.624386
# 2023-02-09  263.619995  -0.011728  2711.526137  3529.139331  817.613194
# 2023-02-10  263.100006  -0.001974  2706.177667  3529.139331  822.961665
# 2023-02-13  271.320007   0.030765  2790.726444  3529.139331  738.412888
# 2023-02-14  272.170013   0.003128  2799.469384  3529.139331  729.669948
#
# [9306 rows x 5 columns]

# %% [markdown]
# ### the maximum drawdown

# %%
micro.drawdowns.max()
#here i fnd the maximum drawdown for the period.
# Out:
# 1325.4200168044358

# %%
micro.drawdowns.idxmax()
#i want to know the date the drawdown took place, thus use the .idxmax function
# Out:
# Timestamp('2022-11-03 00:00:00')

# %%
micro.loc[(micro.index=='2022-06-13')]
#if i want to know other info regarding that particular day when the drawdown took place.
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdowns
# Date
# 2022-06-13  242.259995  -0.043338  2491.822773  3529.139331  1037.316559

# %%
micro.loc[(micro.index<='2022-06-13')]
#now we have info before the drawdown,,we see that the drawdown was increasing.
#i used the <= symbol.
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdowns
# Date
# 1986-03-14    0.100694   0.035089     1.035712     1.035712     0.000000
# 1986-03-17    0.102431   0.017103     1.053578     1.053578     0.000000
# 1986-03-18    0.099826  -0.025761     1.026784     1.053578     0.026794
# 1986-03-19    0.098090  -0.017543     1.008928     1.053578     0.044650
# 1986-03-20    0.095486  -0.026906     0.982144     1.053578     0.071434
# ...                ...        ...          ...          ...          ...
# 2022-06-07  272.500000   0.013857  2802.863539  3529.139331   726.275792
# 2022-06-08  270.410004  -0.007699  2781.366385  3529.139331   747.772947
# 2022-06-09  264.790009  -0.021002  2723.560589  3529.139331   805.578743
# 2022-06-10  252.990005  -0.045587  2602.188852  3529.139331   926.950480
# 2022-06-13  242.259995  -0.043338  2491.822773  3529.139331  1037.316559
#
# [9137 rows x 5 columns]

# %%
#drwadowns in percenatage form.
micro["drawowns%"]=(micro["cummax"]-micro["cummreturns"])/micro["cummax"]
micro
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdowns  \
# Date
# 1986-03-14    0.100694   0.035089     1.035712     1.035712    0.000000
# 1986-03-17    0.102431   0.017103     1.053578     1.053578    0.000000
# 1986-03-18    0.099826  -0.025761     1.026784     1.053578    0.026794
# 1986-03-19    0.098090  -0.017543     1.008928     1.053578    0.044650
# 1986-03-20    0.095486  -0.026906     0.982144     1.053578    0.071434
# ...                ...        ...          ...          ...         ...
# 2023-02-08  266.730011  -0.003107  2743.514945  3529.139331  785.624386
# 2023-02-09  263.619995  -0.011728  2711.526137  3529.139331  817.613194
# 2023-02-10  263.100006  -0.001974  2706.177667  3529.139331  822.961665
# 2023-02-13  271.320007   0.030765  2790.726444  3529.139331  738.412888
# 2023-02-14  272.170013   0.003128  2799.469384  3529.139331  729.669948
#
#             drawowns%
# Date
# 1986-03-14   0.000000
# 1986-03-17   0.000000
# ...

# %%
#this will be the hghest drawdown that we had on microsoft in % form

# %% [markdown]
# ## SMA STRATEGY

# %%
data=micro.Close.loc[(micro.index>="1992-01-01")]
#i now have the data from 1992 to 2022,,the close prices

# %%
data
#converting the data to a data frame
# Out:
# Date
# 1992-01-02      2.375000
# 1992-01-03      2.354167
# 1992-01-06      2.427083
# 1992-01-07      2.500000
# 1992-01-08      2.588542
#                  ...
# 2023-02-08    266.730011
# 2023-02-09    263.619995
# 2023-02-10    263.100006
# 2023-02-13    271.320007
# 2023-02-14    272.170013
# Name: Close, Length: 7839, dtype: float64

# %%
Data=data.to_frame()

# %%
Data
# Out:
#                  Close
# Date
# 1992-01-02    2.375000
# 1992-01-03    2.354167
# 1992-01-06    2.427083
# 1992-01-07    2.500000
# 1992-01-08    2.588542
# ...                ...
# 2023-02-08  266.730011
# 2023-02-09  263.619995
# 2023-02-10  263.100006
# 2023-02-13  271.320007
# 2023-02-14  272.170013
#
# [7839 rows x 1 columns]

# %%
sma_s=50
sma_l=100
#the two M.A

# %%
Data["sma_s"]=Data.Close.rolling(sma_s).mean()
Data["sma_l"]=Data.Close.rolling(sma_l).mean()
#the simple moving averages for the two periods are now visible using the rolling function

# %%
Data
# Out:
#                  Close     sma_s     sma_l
# Date
# 1992-01-02    2.375000       NaN       NaN
# 1992-01-03    2.354167       NaN       NaN
# 1992-01-06    2.427083       NaN       NaN
# 1992-01-07    2.500000       NaN       NaN
# 1992-01-08    2.588542       NaN       NaN
# ...                ...       ...       ...
# 2023-02-08  266.730011  244.1620  240.6636
# 2023-02-09  263.619995  244.5992  240.8524
# 2023-02-10  263.100006  245.0546  241.0382
# 2023-02-13  271.320007  245.3782  241.3269
# 2023-02-14  272.170013  245.7278  241.6591
#
# [7839 rows x 3 columns]

# %%
#we will plot this results on a graph
Data.plot(figsize=(12,8),title="Microsoft-SMA50 SMA100")
# Out:
# <AxesSubplot:title={'center':'Microsoft-SMA50 SMA100'}, xlabel='Date'>

# %%
Data.loc["2018"].plot(figsize=(12,8),title="Microsoft-SMA50 SMA100")
#this will now show the plot for a specific year. using the .loc function.
# Out:
# <AxesSubplot:title={'center':'Microsoft-SMA50 SMA100'}, xlabel='Date'>

# %%
Data.dropna(inplace=True)
Data
#we want to drop the NaN figures.
# Out:
#                  Close       sma_s       sma_l
# Date
# 1992-05-22    2.411458    2.463750    2.504219
# 1992-05-26    2.406250    2.461458    2.504531
# 1992-05-27    2.395833    2.457604    2.504948
# 1992-05-28    2.479167    2.453854    2.505469
# 1992-05-29    2.520833    2.451615    2.505677
# ...                ...         ...         ...
# 2023-02-08  266.730011  244.162000  240.663600
# 2023-02-09  263.619995  244.599200  240.852400
# 2023-02-10  263.100006  245.054600  241.038200
# 2023-02-13  271.320007  245.378200  241.326900
# 2023-02-14  272.170013  245.727800  241.659100
#
# [7740 rows x 3 columns]

# %%
#we are going to show whan to go long and short.
#"sma_s > sma_l we" long and "sma_s < sma_l" we short
Data["position"]=np.where(Data["sma_s"]>Data["sma_l"],1,-1)

# %%
Data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1992-05-22    2.411458    2.463750    2.504219        -1
# 1992-05-26    2.406250    2.461458    2.504531        -1
# 1992-05-27    2.395833    2.457604    2.504948        -1
# 1992-05-28    2.479167    2.453854    2.505469        -1
# 1992-05-29    2.520833    2.451615    2.505677        -1
# ...                ...         ...         ...       ...
# 2023-02-08  266.730011  244.162000  240.663600         1
# 2023-02-09  263.619995  244.599200  240.852400         1
# 2023-02-10  263.100006  245.054600  241.038200         1
# 2023-02-13  271.320007  245.378200  241.326900         1
# 2023-02-14  272.170013  245.727800  241.659100         1
#
# [7740 rows x 4 columns]

# %%
#so now we are going to plot the positions on a graph.
Data.loc[:,["sma_s","sma_l","position"]].plot(figsize=(12,8),title="Microsoft-SMA50 SMA100")
# Out:
# <AxesSubplot:title={'center':'Microsoft-SMA50 SMA100'}, xlabel='Date'>

# %%
Data.loc[:,["sma_s","sma_l","position"]].plot(figsize=(12,8),title="Microsoft-SMA50 SMA100",secondary_y="position")
#here i added the "secondary_y"function so that i could plot the long and short positions for all the years.
# Out:
# <AxesSubplot:title={'center':'Microsoft-SMA50 SMA100'}, xlabel='Date'>

# %%
Data.loc["2019":,["sma_s","sma_l","position"]].plot(figsize=(12,8),title="Microsoft-SMA50 SMA100",secondary_y="position")
#this line of code shows the long and short positions for the year 2019.
# Out:
# <AxesSubplot:title={'center':'Microsoft-SMA50 SMA100'}, xlabel='Date'>

# %%
Data["returns b&h"]= np.log(Data.Close.div(Data.Close.shift(1)))
#we nnow need to backtest strategy and see how it works.
#so we calculate the buy and hold retruns for microsoft.

# %%
Data
# Out:
#                  Close       sma_s       sma_l  position  returns b&h
# Date
# 1992-05-22    2.411458    2.463750    2.504219        -1          NaN
# 1992-05-26    2.406250    2.461458    2.504531        -1    -0.002162
# 1992-05-27    2.395833    2.457604    2.504948        -1    -0.004339
# 1992-05-28    2.479167    2.453854    2.505469        -1     0.034192
# 1992-05-29    2.520833    2.451615    2.505677        -1     0.016667
# ...                ...         ...         ...       ...          ...
# 2023-02-08  266.730011  244.162000  240.663600         1    -0.003107
# 2023-02-09  263.619995  244.599200  240.852400         1    -0.011728
# 2023-02-10  263.100006  245.054600  241.038200         1    -0.001974
# 2023-02-13  271.320007  245.378200  241.326900         1     0.030765
# 2023-02-14  272.170013  245.727800  241.659100         1     0.003128
#
# [7740 rows x 5 columns]

# %%
Data["Strategy"]=Data["returns b&h"]*Data.position.shift(1)
Data
#this line of code will help in calculating the data for the strategy.
#the retrunsb&h only accounts for when you go long 
#the strategy coulmn will show the returns when we also go short.
# Out:
#                  Close       sma_s       sma_l  position  returns b&h  \
# Date
# 1992-05-22    2.411458    2.463750    2.504219        -1          NaN
# 1992-05-26    2.406250    2.461458    2.504531        -1    -0.002162
# 1992-05-27    2.395833    2.457604    2.504948        -1    -0.004339
# 1992-05-28    2.479167    2.453854    2.505469        -1     0.034192
# 1992-05-29    2.520833    2.451615    2.505677        -1     0.016667
# ...                ...         ...         ...       ...          ...
# 2023-02-08  266.730011  244.162000  240.663600         1    -0.003107
# 2023-02-09  263.619995  244.599200  240.852400         1    -0.011728
# 2023-02-10  263.100006  245.054600  241.038200         1    -0.001974
# 2023-02-13  271.320007  245.378200  241.326900         1     0.030765
# 2023-02-14  272.170013  245.727800  241.659100         1     0.003128
#
#             Strategy
# Date
# 1992-05-22       NaN
# 1992-05-26  0.002162
# 1992-05-27  0.004339
# 1992-05-28 -0.034192
# ...

# %%
Data.dropna(inplace=True)
#dropping the NaN values

# %%
Data[["returns b&h","Strategy"]].sum()
#use this code to find the performance of both the strategies ie "b&h" and "strategy"
#the ".sum" function is used.
#in this case the "returnsb&h" beat  the "strategy" in terms of their performance.
# Out:
# returns b&h    4.726195
# Strategy       1.637587
# dtype: float64

# %%
Data[["returns b&h","Strategy"]].sum().apply(np.exp)
#we use this code to find the absolute performance of both strategies
#basically $1 investment through buy and hold will yield $96 and stratrgy will yield $5
# Out:
# returns b&h    112.865334
# Strategy         5.142744
# dtype: float64

# %%
Data[["returns b&h","Strategy"]].std()*np.sqrt(252)
#used this code to find the annual sd. for both strategies.
#from the results i czn see that the sd is not that different for both strategies, 
#whether i buy and hold or take the strategy approach, therefore it's not that beneficial to take either strategy
# Out:
# returns b&h    0.314295
# Strategy       0.314426
# dtype: float64

# %%
Data.Close.plot(figsize=(12,8))
#generally from this plot i see all i ahve to do is go long.
#i'll create a strategy whereby i dont go short.
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Strategy adjusted for long bias

# %%
Data["position2"]=np.where(Data["sma_s"]>Data["sma_l"],1,0)
#this line of code will now only show long positions "1" namely "position2"

# %%
Data["strategy2"]=Data["returns b&h"]*Data.position2.shift(1)
Data.dropna(inplace=True)
Data
# Out:
#                  Close       sma_s       sma_l  position  returns b&h  \
# Date
# 1992-05-27    2.395833    2.457604    2.504948        -1    -0.004339
# 1992-05-28    2.479167    2.453854    2.505469        -1     0.034192
# 1992-05-29    2.520833    2.451615    2.505677        -1     0.016667
# 1992-06-01    2.588542    2.450260    2.505677        -1     0.026505
# 1992-06-02    2.559896    2.447917    2.504766        -1    -0.011128
# ...                ...         ...         ...       ...          ...
# 2023-02-08  266.730011  244.162000  240.663600         1    -0.003107
# 2023-02-09  263.619995  244.599200  240.852400         1    -0.011728
# 2023-02-10  263.100006  245.054600  241.038200         1    -0.001974
# 2023-02-13  271.320007  245.378200  241.326900         1     0.030765
# 2023-02-14  272.170013  245.727800  241.659100         1     0.003128
#
#             Strategy  position2  strategy2
# Date
# 1992-05-27  0.004339          0  -0.000000
# ...

# %%
Data[["returns b&h","strategy2"]].sum()
#we now compare the performance of strategy2 and that of returns buy and hold.
#strategy 2 now has improved performance to 3.099484
# Out:
# returns b&h    4.728357
# strategy2      3.181891
# dtype: float64

# %%
Data[["returns b&h","strategy2"]].sum().apply(np.exp)
#now the absolute performnce of strategy has improved from 5.06 to 22.18
#means that by taking a long bias strategy performance increases as compared to taking a long short strategy
# Out:
# returns b&h    113.109616
# strategy2       24.092270
# dtype: float64

# %%
Data[["returns b&h","strategy2"]].std()*np.sqrt(252)
#annualised std of both strategies
#we see std for strategy2 reduced from 0.3134 to 0.230163 meaning reduced risk uptake.
#the second strategy with long bias made better returns.
# Out:
# returns b&h    0.314315
# strategy2      0.229720
# dtype: float64

# %%
## strategy 2 is better than strategy 1

# %%
Data[["Strategy","strategy2"]].std()*np.sqrt(252)
#THIS IS A COMPARISON BETWEEN THE STD. FOR STRATEGY AND STRATEGY 2, STRATEGY 2 IS BETTER
# Out:
# Strategy     0.314447
# strategy2    0.229720
# dtype: float64

# %% [markdown]
# # Creating our first function

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std=data["strategy"].std()*np.sqrt(252)
    
    return ret,std
#I created a function that will be used to test strategies,
#so i had to define all this variables that will be key in determing the absolute returns and std of any stock.
#The ticker symbol is stored in stock togehter with the end and start date.
#then we use the values obtained to calculate the returns,SMA, calculate the retuns for the various strategies.

# %%
test_strategy("NVDA","2000-01-01","2022-01-01",(50,200))
#now we see that the absolute returns are 0.88 and std of 29.65%(MICROSOFT)
#means that $1 that was invested using the strategy method is now $0.88(MICROSOFT)
#I CAN USE THIS CODE OFR ANY TICKER SYMBOL
# Out:
# [*********************100%***********************]  1 of 1 completed
# (63.338948778207424, 0.5559640659982722)

# %% [markdown]
# ## Creating a class

# %%
class SMABACKTESTER():
    def __init__(self,symbol,SMA_S,SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
        
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    
    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data
        
        ret=np.exp(data["strategy"].sum())
        std=data["strategy"].std()*np.sqrt(252)
    
        #return for the performance and outperformance
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{}]| SMA_S={} | SMA_L{}".format(self.symbol,self.SMA_S,self.SMA_L)
            self.results[["returnsbh","returnstrategy"]].plot(figsize=(12,8), title=title)

# %%
tester=SMABACKTESTER("MSFT",50,100, "2010-01-01","2020-01-01")
#THIS IS FOR DOWNLOADING THE DATA USING THE get_data FUNCTION ABOVE.
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
#THIS CODE WILL CALL THE CLASS FUNCTION FOR test_results
#PRINTS THE PERFROMANCE OF 1.178 AND OUTPERFORMANCE BY -4.870
# Out:
# (1.178457, -4.870641)

# %%
tester.plot_results()
