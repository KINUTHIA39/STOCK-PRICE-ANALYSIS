# %%
from SMABACKTester import SMABACKTESTER

# %%
tester=SMABACKTESTER("TSLA",50,100, "2010-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (1.276077, -12.90941)

# %%
tester.plot_results()
